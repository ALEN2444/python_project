# %%
file = open('data.csv','x')
file.close()

# %%
import pandas as pd
df = pd.read_csv('data.csv')
df
# Out:
#    sn   name  age    address
# 0   1    Ram   24  Kathmandu
# 1   2  Shyam   22   Lalitpur
# 2   3   Hari   19  Bhaktapur
# 3   4   Sita   20       Bali
# 4   5  Bipin   21  Manhattan

# %%
import pandas as pd
df = pd.read_csv('data.csv')
df.head(3)
# Out:
#    sn   name  age    address
# 0   1    Ram   24  Kathmandu
# 1   2  Shyam   22   Lalitpur
# 2   3   Hari   19  Bhaktapur

# %%
df.tail(2)
# Out:
#    sn   name  age    address
# 3   4   Sita   20       Bali
# 4   5  Bipin   21  Manhattan

# %%
df = pd.read_csv('data.csv', index_col = 'sn')
df
# Out:
#      name  age    address
# sn
# 1     Ram   24  Kathmandu
# 2   Shyam   22   Lalitpur
# 3    Hari   19  Bhaktapur
# 4    Sita   20       Bali
# 5   Bipin   21  Manhattan

# %%
df = pd.read_csv('data.csv',index_col = 'sn', usecols = ['sn','name', 'age'])
df
# Out:
#      name  age
# sn
# 1     Ram   24
# 2   Shyam   22
# 3    Hari   19
# 4    Sita   20
# 5   Bipin   21

# %%
# iloc and loc
df.iloc[0:5]
# Out:
#      name  age
# sn
# 1     Ram   24
# 2   Shyam   22
# 3    Hari   19
# 4    Sita   20
# 5   Bipin   21

# %%
df = pd.read_csv('data.csv',index_col = 'sn')
df.loc[2:5]
# Out:
#      name  age    address
# sn
# 2   Shyam   22   Lalitpur
# 3    Hari   19  Bhaktapur
# 4    Sita   20       Bali
# 5   Bipin   21  Manhattan

# %%
df = pd.read_csv('data.csv',index_col = 'name',)
df.loc["Hari":"Bipin"]
# Out:
#        sn  age    address
# name
# Hari    3   19  Bhaktapur
# Sita    4   20       Bali
# Bipin   5   21  Manhattan

# %%
df = pd.read_csv('data.csv',index_col = 'sn')
df[df['name']== 'Ram']
# Out:
#    name  age    address
# sn
# 1   Ram   24  Kathmandu

# %%
df = pd.read_csv('data.csv',index_col = 'sn')
df['name']== 'Ram'
# Out:
# sn
# 1     True
# 2    False
# 3    False
# 4    False
# 5    False
# Name: name, dtype: bool

# %%
df = pd.read_csv('data.csv',index_col = 'sn')
df = df[df['age']<22]
df.to_csv('new_data.csv')

# %%
data = {'name':['Ram','Shyam','Hari'],
       'age':[45,65,22],
       'address':['kathmandu','Bhaktapur','patan']}
df = pd.DataFrame(data)
df
# Out:
#     name  age    address
# 0    Ram   45  kathmandu
# 1  Shyam   65  Bhaktapur
# 2   Hari   22      patan

# %%
data = [['name','age','address'],
       ['Ram',45,'Kathmandu'],
       ['sita',44,'bhaktapur'],
       ['gita',22,'lalitpur']]
import csv
file = open('list_data.csv','w')
x = csv.writer(file)
x.writerows(data)
file.close()

# %%
df = pd.read_csv('list_data.csv')
df
# Out:
#    name  age    address
# 0   Ram   45  Kathmandu
# 1  sita   44  bhaktapur
# 2  gita   22   lalitpur
